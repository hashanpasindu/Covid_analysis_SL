# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df=pd.read_csv('owid-covid-data.csv')

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
continent_df=pd.DataFrame()

# %%
df.dtypes
# Out:
# iso_code                                  object
# continent                                 object
# location                                  object
# date                                      object
# total_cases                              float64
# new_cases                                float64
# new_cases_smoothed                       float64
# total_deaths                             float64
# new_deaths                               float64
# new_deaths_smoothed                      float64
# total_cases_per_million                  float64
# new_cases_per_million                    float64
# new_cases_smoothed_per_million           float64
# total_deaths_per_million                 float64
# new_deaths_per_million                   float64
# new_deaths_smoothed_per_million          float64
# reproduction_rate                        float64
# icu_patients                             float64
# icu_patients_per_million                 float64
# ...

# %%
df.head()
# Out:
#   iso_code continent     location        date  total_cases  new_cases  \
# 0      AFG      Asia  Afghanistan  2020-02-24          1.0        1.0
# 1      AFG      Asia  Afghanistan  2020-02-25          1.0        0.0
# 2      AFG      Asia  Afghanistan  2020-02-26          1.0        0.0
# 3      AFG      Asia  Afghanistan  2020-02-27          1.0        0.0
# 4      AFG      Asia  Afghanistan  2020-02-28          1.0        0.0
#
#    new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# 0                 NaN           NaN         NaN                  NaN  ...
# 1                 NaN           NaN         NaN                  NaN  ...
# 2                 NaN           NaN         NaN                  NaN  ...
# 3                 NaN           NaN         NaN                  NaN  ...
# 4                 NaN           NaN         NaN                  NaN  ...
#
#    gdp_per_capita  extreme_poverty  cardiovasc_death_rate  \
# ...

# %%
group_df=df.groupby('continent')

# %%
df[df['iso_code']=='LKA']
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 52992      LKA      Asia  Sri Lanka  2020-01-27          1.0        1.0
# 52993      LKA      Asia  Sri Lanka  2020-01-28          1.0        0.0
# 52994      LKA      Asia  Sri Lanka  2020-01-29          1.0        0.0
# 52995      LKA      Asia  Sri Lanka  2020-01-30          1.0        0.0
# 52996      LKA      Asia  Sri Lanka  2020-01-31          1.0        0.0
# ...        ...       ...        ...         ...          ...        ...
# 53355      LKA      Asia  Sri Lanka  2021-01-24      58430.0      843.0
# 53356      LKA      Asia  Sri Lanka  2021-01-25      59167.0      737.0
# 53357      LKA      Asia  Sri Lanka  2021-01-26      59922.0      755.0
# 53358      LKA      Asia  Sri Lanka  2021-01-27      60694.0      772.0
# 53359      LKA      Asia  Sri Lanka  2021-01-28      61586.0      892.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
result=df[df['iso_code']=='LKA'].sort_values(by=['date'])

# %%
result
# Out:
#       iso_code continent   location        date  total_cases  new_cases  \
# 52992      LKA      Asia  Sri Lanka  2020-01-27          1.0        1.0
# 52993      LKA      Asia  Sri Lanka  2020-01-28          1.0        0.0
# 52994      LKA      Asia  Sri Lanka  2020-01-29          1.0        0.0
# 52995      LKA      Asia  Sri Lanka  2020-01-30          1.0        0.0
# 52996      LKA      Asia  Sri Lanka  2020-01-31          1.0        0.0
# ...        ...       ...        ...         ...          ...        ...
# 53355      LKA      Asia  Sri Lanka  2021-01-24      58430.0      843.0
# 53356      LKA      Asia  Sri Lanka  2021-01-25      59167.0      737.0
# 53357      LKA      Asia  Sri Lanka  2021-01-26      59922.0      755.0
# 53358      LKA      Asia  Sri Lanka  2021-01-27      60694.0      772.0
# 53359      LKA      Asia  Sri Lanka  2021-01-28      61586.0      892.0
#
#        new_cases_smoothed  total_deaths  new_deaths  new_deaths_smoothed  ...  \
# ...

# %%
result2=result[['date','new_cases']]

# %%
result2.index = pd.to_datetime(result2.index)

# %%
result2.drop(['date'], axis=1, inplace=True)
# Out:
# C:\Users\hashanp\Anaconda3\lib\site-packages\pandas\core\frame.py:4163: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
result2.index=result['date']

# %%
result2
# Out:
#             new_cases
# date
# 2020-01-27        1.0
# 2020-01-28        0.0
# 2020-01-29        0.0
# 2020-01-30        0.0
# 2020-01-31        0.0
# ...               ...
# 2021-01-24      843.0
# 2021-01-25      737.0
# 2021-01-26      755.0
# 2021-01-27      772.0
# 2021-01-28      892.0
#
# [368 rows x 1 columns]

# %%
result2.index = pd.to_datetime(result2.index)

# %%
result2.index
# Out:
# DatetimeIndex(['2020-01-27', '2020-01-28', '2020-01-29', '2020-01-30',
#                '2020-01-31', '2020-02-01', '2020-02-02', '2020-02-03',
#                '2020-02-04', '2020-02-05',
#                ...
#                '2021-01-19', '2021-01-20', '2021-01-21', '2021-01-22',
#                '2021-01-23', '2021-01-24', '2021-01-25', '2021-01-26',
#                '2021-01-27', '2021-01-28'],
#               dtype='datetime64[ns]', name='date', length=368, freq=None)

# %%
f, ax = plt.subplots(1, 1)
ax.plot(result2['new_cases'])
ax.set_title('Time-Series graph for new COVID cases in Sri Lanka')
ax.tick_params(axis='x', rotation=45)
plt.show()
plt.close()

# %%
result2.sort_index(ascending=True, inplace=True)

# %%
rollingmean = result2['new_cases'].rolling(window=50, center=False).mean()
rollingstd = result2['new_cases'].rolling(window=50, center=False).std()

ewmmean = plt.plot(rollingmean, 
                color='green',
                label='Rolling Mean')
std = plt.plot(rollingstd,
               color='black',
               label='Rolling Std')
log = plt.plot(result2['new_cases'],
               color='red',
               label='Original')
plt.legend(loc='best')
plt.title('Time-Series graph for new COVID cases in Sri Lanka')
plt.xticks(rotation=45)
plt.show(block=False)
plt.close()

# %%
from statsmodels.tsa.stattools import adfuller

# %%
adfuller(result2['new_cases'], autolag='AIC')
# Out:
# (1.1631142971138626,
#  0.9957208621028203,
#  17,
#  350,
#  {'1%': -3.4491725955218655,
#   '5%': -2.8698334971428574,
#   '10%': -2.5711883591836733},
#  4006.275498741195)

# %%
import numpy as np

# %%
result2['new_cases'] = result2['new_cases'].apply(lambda x: np.log(x))
# Out:
# <ipython-input-187-a117f9cccc15>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result2['new_cases'] = result2['new_cases'].apply(lambda x: np.log(x))

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
decomposition = seasonal_decompose(result2['new_cases'], freq = 180)
# Out:
# <ipython-input-208-1de60040a840>:1: FutureWarning: the 'freq'' keyword is deprecated, use 'period' instead
#   decomposition = seasonal_decompose(result2['new_cases'], freq = 180)

# %%
result2.loc[:,'trend'] = decomposition.trend
result2.loc[:, 'seasonal'] = decomposition.seasonal
result2.loc[:, 'residual'] = decomposition.resid
# Out:
# C:\Users\hashanp\Anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# C:\Users\hashanp\Anaconda3\lib\site-packages\pandas\core\indexing.py:1783: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[item_labels[indexer[info_axis]]] = value

# %%
f, (ax1, ax2, ax3) = plt.subplots(1,3, figsize = (15, 5), sharex = True)
ax1.plot(result2['trend'], label='Original')
ax1.legend(loc='best')
ax1.tick_params(axis = 'x', rotation = 45)

ax2.plot(result2['seasonal'], label='Seasonal')
ax2.legend(loc='best')
ax2.tick_params(axis = 'x', rotation = 45)

ax3.plot(result2['residual'], label='Residual')
ax3.legend(loc='best')
ax3.tick_params(axis = 'x', rotation = 45)
